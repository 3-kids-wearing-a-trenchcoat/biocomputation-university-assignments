# %%
# imports
import numpy as np
import pandas as pd
from pathlib import Path
from Individual import Individual, FTYPE
from Population import Population
from RNASeqDeconvolution import RNASeqDeconvolution
from main import compare, set_parameters, compare_to_true_results
# TODO: look at larger (including MUCH larger) population sizes, I suspect early convergence happens because of too few individuals who can carry unique changes
# I should also look at mutation rates and sigmas relative to these larger sizes, I reckon these factor more than anything are why my shit is sub-par

# %%
output = compare("mut_standard_deviation", 1, 3, 10, "mut_prob", 1e-6, 1e-6, 1e-5)
output
# Out:
#   0%|                                                                                                                                                                                                                       | 0/4 [00:00<?, ?it/s]
#   0%|                                                                                                                                                                                           | 0/4 [00:00<?, ?it/s, mut_standard_deviation = 1]
#   0%|                                                                                                                                                                                                    | 0/10 [00:00<?, ?it/s, mut_prob = 1e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  10%|██████████████████▊                                                                                                                                                                         | 1/10 [00:11<01:46, 11.81s/it, mut_prob = 1e-06]
#  10%|██████████████████▊                                                                                                                                                                         | 1/10 [00:11<01:46, 11.81s/it, mut_prob = 2e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  20%|█████████████████████████████████████▌                                                                                                                                                      | 2/10 [00:29<01:59, 14.99s/it, mut_prob = 2e-06]
#  20%|█████████████████████████████████████▌                                                                                                                                                      | 2/10 [00:29<01:59, 14.99s/it, mut_prob = 3e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  30%|████████████████████████████████████████████████████████▍                                                                                                                                   | 3/10 [00:32<01:08,  9.83s/it, mut_prob = 3e-06]
#  30%|████████████████████████████████████████████████████████▍                                                                                                                                   | 3/10 [00:32<01:08,  9.83s/it, mut_prob = 4e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  40%|███████████████████████████████████████████████████████████████████████████▏                                                                                                                | 4/10 [01:53<03:46, 37.79s/it, mut_prob = 4e-06]
#  40%|████████████████████████████████████████████████████████████████████▍                                                                                                      | 4/10 [01:53<03:46, 37.79s/it, mut_prob = 4.9999999999999996e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  50%|█████████████████████████████████████████████████████████████████████████████████████▌                                                                                     | 5/10 [03:12<04:23, 52.63s/it, mut_prob = 4.9999999999999996e-06]
#  50%|██████████████████████████████████████████████████████████████████████████████████████                                                                                      | 5/10 [03:12<04:23, 52.63s/it, mut_prob = 5.999999999999999e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  60%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                    | 6/10 [04:31<04:06, 61.51s/it, mut_prob = 5.999999999999999e-06]
#  60%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                    | 6/10 [04:31<04:06, 61.51s/it, mut_prob = 6.999999999999999e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  70%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                   | 7/10 [05:50<03:21, 67.23s/it, mut_prob = 6.999999999999999e-06]
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                        | 7/10 [05:50<03:21, 67.23s/it, mut_prob = 8e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                     | 8/10 [06:54<02:12, 66.28s/it, mut_prob = 8e-06]
#  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                     | 8/10 [06:54<02:12, 66.28s/it, mut_prob = 9e-06]
# running RNA-seq deconvolution:   0%|                                                                          …
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                  | 9/10 [07:57<01:05, 65.36s/it, mut_prob = 9e-06]
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                  | 9/10 [07:57<01:05, 65.36s/it, mut_prob = 1e-05]
# running RNA-seq deconvolution:   0%|                                                                          …
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [09:02<00:00, 65.15s/it, mut_prob = 1e-05]
#  25%|████████████████████████████████████████████▌                                                                                                                                     | 1/4 [09:02<27:06, 542.33s/it, mut_standard_deviation = 4]
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
#  50%|█████████████████████████████████████████████████████████████████████████████████████████                                                                                         | 2/4 [15:46<15:21, 460.95s/it, mut_standard_deviation = 7]
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                            | 3/4 [22:45<07:21, 441.87s/it, mut_standard_deviation = 10]
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
# running RNA-seq deconvolution:   0%|                                                                          …
#                              mut_prob = 1e-06  mut_prob = 2e-06  \
# mut_standard_deviation = 1       28187.273675      28169.570899
# mut_standard_deviation = 4       28188.783778      28186.364366
# mut_standard_deviation = 7       28182.868071      28190.362371
# mut_standard_deviation = 10      28188.816944      28194.906618
#
#                              mut_prob = 3e-06  mut_prob = 4e-06  \
# mut_standard_deviation = 1       28217.913823      28165.420235
# mut_standard_deviation = 4       28217.913823      28134.203579
# mut_standard_deviation = 7       28217.913823      28171.965385
# mut_standard_deviation = 10      28215.355025      28186.616653
#
#                              mut_prob = 4.9999999999999996e-06  \
# mut_standard_deviation = 1                        28107.302367
# mut_standard_deviation = 4                        28181.460487
# mut_standard_deviation = 7                        28125.594678
# mut_standard_deviation = 10                       28155.219335
#
#                              mut_prob = 5.999999999999999e-06  \
# mut_standard_deviation = 1                       28106.821485
# mut_standard_deviation = 4                       28152.416694
# mut_standard_deviation = 7                       28142.948853
# mut_standard_deviation = 10                      28148.279302
#
#                              mut_prob = 6.999999999999999e-06  \
# mut_standard_deviation = 1                       28096.320681
# mut_standard_deviation = 4                       28110.662001
# mut_standard_deviation = 7                       28121.302568
# mut_standard_deviation = 10                      28127.782984
#
#                              mut_prob = 8e-06  mut_prob = 9e-06  \
# mut_standard_deviation = 1       28092.220302      28084.595742
# mut_standard_deviation = 4       28093.030470      28083.896127
# mut_standard_deviation = 7       28085.028089      28091.408971
# mut_standard_deviation = 10      28081.767334      28125.082118
#
#                              mut_prob = 1e-05
# mut_standard_deviation = 1       28074.988406
# mut_standard_deviation = 4       28082.779960
# mut_standard_deviation = 7       28088.788376
# mut_standard_deviation = 10      28091.718970

# %%
output = compare("mut_prob", 0.00001, 0.00001, 0.0001, "mut_standard_deviation", 1, 1, 10)
output

# %%
# experiment = set_parameters({"pop_size": 200, "mut_standard_deviation": 0.01, "max_iter": 50000})
# experiment.run()
# phen = experiment.result

# %%
# print(experiment.result_fitness_score)

# %%
# compare_to_true_results(phen)
