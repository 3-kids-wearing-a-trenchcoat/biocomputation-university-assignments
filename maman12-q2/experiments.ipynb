# %%
# imports
import numpy as np
import pandas as pd
from pathlib import Path
from Individual import Individual, FTYPE
from Population import Population
from RNASeqDeconvolution import RNASeqDeconvolution
from main import compare

# %%
output = compare("pop_size", 100, 100, 1000)
output[0]
# Out:
# ...
#   0%|                                                                                                                                                                                        | 0/15 [00:00<?, ?it/s, mut_standard_deviation = 0.1]
# running RNA-seq deconvolution:   0%|                                                                          …
# ...
#   7%|██████████▋                                                                                                                                                     | 1/15 [01:24<19:37, 84.12s/it, mut_standard_deviation = 0.15000000000000002]
# running RNA-seq deconvolution:   0%|                                                                          …
# ...
#  13%|███████████████████████▍                                                                                                                                                        | 2/15 [02:42<17:28, 80.63s/it, mut_standard_deviation = 0.2]
# ...

# %%
# df_arr = compare("stagnation_limit", 300, 100, 500, "rng_seed", 1111, 1111, 9999)
# df_arr[0]
# Out:
#                                          mut_standard_deviation = 0.1  \
# mut_prob = 0.001                  200 consecutive stagnant iterations
# mut_prob = 0.0015                                     iteration limit
# mut_prob = 0.002                                      iteration limit
# mut_prob = 0.0025                 200 consecutive stagnant iterations
# mut_prob = 0.003                  200 consecutive stagnant iterations
# mut_prob = 0.0035                 200 consecutive stagnant iterations
# mut_prob = 0.004                  200 consecutive stagnant iterations
# mut_prob = 0.0045000000000000005  200 consecutive stagnant iterations
# mut_prob = 0.005000000000000001   200 consecutive stagnant iterations
# mut_prob = 0.005500000000000001                       iteration limit
# mut_prob = 0.006000000000000002                       iteration limit
# mut_prob = 0.006500000000000002                       iteration limit
# ...
